# %%
import math

Name = input("Enter your name")
Age = int(input("Enter your age"))
Height = int(input("Enter your height in cms"))
Weight = int(input("Enter you weight in kgs"))

print(Name.lower())
print(Name.upper())
print(len(Name))

Height = Height/100

BMI = Weight/(Height*Height)
print('Your BMI is', BMI)

print(Weight/math.pi)

print('Age in days ', Age * 365)

for char in Name:
    print(char)
# Out:
# Enter your name yash
# Enter your age 24
# Enter your height in cms 159
# Enter you weight in kgs 77
# yash
# YASH
# 4
# Your BMI is 30.457655947153988
# 24.50986123615188
# Age in days  8760
# y
# a
# s
# h

# %%
num1 = int(input('Enter a number'))
num2 = int(input('Enter a number'))

print('Sum: ', num1+num2)
print('Product: ', num1*num2)
print('Difference: ', math.fabs(num1-num2))
print('Quotient: ', num1%num2)
# Out:
# Enter a number 11
# Enter a number 2
# Sum:  13
# Product:  22
# Difference:  9.0
# Quotient:  1
